# %%
import os
os.chdir('../')
from bowie_makeplot.make_plot import plot_main
import matplotlib.pyplot as plt
% matplotlib inline
import numpy as np
# Out:
# /Users/michaelkatz/anaconda3/envs/testenv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/michaelkatz/anaconda3/envs/testenv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/michaelkatz/anaconda3/envs/testenv/lib/python3.5/site-packages/astropy/utils/introspection.py:147: UserWarning: Module bowie_makeplot was already imported from None, but /Users/michaelkatz/Documents/Research/PythonCodes/BOWIE_analysis is being added to sys.path
#   from pkg_resources import parse_version
# ...

# %%
codet_pot_dict = {
"general":{
    "WORKING_DIRECTORY": "notebooks/paper_data",

    "SNR_CUT": 5.0,

    "spacing":"wide",
    "x_column_label": "M_s",
    "y_column_label": "d_L", 

    "figure_width": 13.0,
    "figure_height": 7.0,
    
    "num_rows": 3,
    "num_cols": 2,

    "xlims": [0.0, 5.0],
    "dx": 1.0,
    "xscale": "log",

    "ylims": [1.0, 5.0],
    "dy": 1.0,
    "yscale": "log",
    },



"plot_info":
    {
    "0":{
        "file":[
            {"name":"LISA_small_binaries_100_year.hdf5",
             "label":"LISA_prop_curve_all"}
            ],
        "type":"Waterfall",
        },
        
    "2":{
        "file":[
            {"name":"LIGO_q8_s8.hdf5",
             "label":"LIGO_ASD_all"}
            ],
        "type":"Waterfall",
        },
        
    "1":
        {"indices": [0,2],
        "type": "Horizon"
        },
    
    "3":{
        "indices": 0,
        "type": "Ratio",
        "control":
            {"index": 2},
        "label":
            {"title": "Parallel vs. Anti-Parallel Spins", 
             "title_fontsize": 18,  "xlabel": r"Total Mass ($M_\odot$)", 
             "ylabel": "Redshift"},
        #"extra":
        #    {"ratio_contour_lines":True}
        },
    "4":{
        "indices": 0,
        "type": "CodetectionPotential",
        "control":
            {"index": 2},
        "label":
            {"title": "Parallel vs. Anti-Parallel Spins", 
             "title_fontsize": 18,  "xlabel": r"Total Mass ($M_\odot$)", 
             "ylabel": "Redshift"},
        "limits":
            {"ylims":[0.0, 10.0]}
        #"extra":
        #    {"ratio_contour_lines":True}
        },
    "5":{
        "indices": 0,
        "type": "CodetectionPotential",
        "control":
            {"index": 2},
        "label":
            {"title": "Parallel vs. Anti-Parallel Spins", 
             "title_fontsize": 18,  "xlabel": r"Total Mass ($M_\odot$)", 
             "ylabel": "Redshift"},
        #"extra":
        #    {"ratio_contour_lines":True}
        },
    }
}

plot_main(codet_pot_dict)
# Out:
# /Users/michaelkatz/anaconda3/envs/testenv/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /Users/michaelkatz/anaconda3/envs/testenv/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ...

# %%
codet_pot_dict = {
"general":{
    "WORKING_DIRECTORY": "paper_data",

    "SNR_CUT": 5.0,

    "spacing":"tight",
    "x_column_label": "M_s",
    "y_column_label": "d_L", 

    "figure_width": 13.0,
    "figure_height": 7.0,
        
    "fig_y_label":"Luminosity Distance (Mpc)",
    "fig_x_label": r"Source Frame Total Mass ($M_\odot$)",

    "num_rows": 5,
    "num_cols": 2,

    "xlims": [0.0, 5.0],
    "dx": 1.0,
    "xscale": "log",

    "ylims": [0.0, 5.0],
    "dy": 1.0,
    "yscale": "log",
    "colorbars":
        {
        "CodetectionPotential":{"pos":1, "ticks_fontsize":14}, 
        "SingleDetection":{"pos":2, "ticks_fontsize":14}, 
        "Waterfall":{"pos":3, "ticks_fontsize":14}
        }
    },



"plot_info":
    {
        #setup waterfalls

    "0":{
        "file":
            [
            {"name":"LIGO_q8_s8.hdf5","label":"LIGO_ASD_all"}
            ],
        "type": "Waterfall",
        "label":
            {"ylabel": "aLIGO", "ylabel_fontsize":12},
        "extra":
            {"ratio_contour_lines":True}
        },
        
     "2":{
        "file":
            [
            {"name":"LISA_small_binaries_5_year.hdf5","label":"LISA_prop_curve_all"}
            ],
        "type": "Waterfall",
        "label":
            {"ylabel": "LISA: 5 year", "ylabel_fontsize":12},
        "extra":
            {"ratio_contour_lines":True}
        },
        
     "4":{
        "file":
            [
            {"name":"LISA_small_binaries_10_year.hdf5","label":"LISA_prop_curve_all"}
            ],
        "type": "Waterfall",
        "label":
            {"ylabel": "LISA: 10 year", "ylabel_fontsize":12},
        "extra":
            {"ratio_contour_lines":True}
        },
        
     "6":{
        "file":
            [
            {"name":"LISA_small_binaries_50_year.hdf5","label":"LISA_prop_curve_all"}
            ],
        "type": "Waterfall",
        "label":
            {"ylabel": "LISA: 50 year", "ylabel_fontsize":12},
        "extra":
            {"ratio_contour_lines":True}
        },
        
     "8":{
        "file":
            [
            {"name":"LISA_small_binaries_100_year.hdf5","label":"LISA_prop_curve_all"}
            ],
        "type": "Waterfall",
        "label":
            {"ylabel": "LISA: 100 year", "ylabel_fontsize":12},
        "extra":
            {"ratio_contour_lines":True}
        },
        
    #Horizon on top right
    "1":{
        "indices":[0,2,4,6,8],
        "type": "Horizon",
        "extra":
            {"ratio_contour_lines":True},
        "legend":
            {
            "labels":["Ligo", "LISA 5 Year", "LISA 10 Year", "LISA 50 Year", "LISA 100 Year"],
            "ncol": 3,
            "bbox_to_anchor": [0.0, 1.6]
            }
        },
        
    "3":{
        "indices": 2,
        "type": "CodetectionPotential",
        "control":
            {"index": 0},
        "extra":
            {"ratio_contour_lines":True}
        },
        
    "5":{
        "indices": 4,
        "type": "CodetectionPotential",
        "control":
            {"index": 0},
        "extra":
            {"ratio_contour_lines":True}
        },
        
    "7":{
        "indices": 6,
        "type": "CodetectionPotential",
        "control":
            {"index": 0},
        "extra":
            {"ratio_contour_lines":True}
        },
        
    "9":{
        "indices": 8,
        "type": "CodetectionPotential",
        "control":
            {"index": 0},
        "extra":
            {"ratio_contour_lines":True}
        }
    }
}

plot_main(codet_pot_dict)

# %%
CHECKER
